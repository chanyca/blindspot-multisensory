# %% [markdown]
# # Set Up and Declare Files

# %% [markdown]
# https://github.com/djangraw/ParseEyeLinkAscFiles

# %%
# ParseEyeLinkAsc_script.ipynb
#
# Created 8/15/18 by DJ.
# Modified by AC for data analysis

# %%
# Imports
import os

# plotting
import matplotlib.pyplot as plt

# data handling
import pandas as pd
import numpy as np
import shutil
import time
from ParseEyeLinkAsc import ParseEyeLinkAsc

# %%
# Paths

dataDir = 'edf/asc'
plotDir = '../plots/eyelink'
if not os.path.exists(plotDir):
    os.makedirs(plotDir)
# print(plotDir)
ascFiles = [file for file in os.listdir(dataDir) if file.endswith('.asc')]
# print(ascFiles)

outDir = os.path.join(dataDir, 'ParseEyeLinkAsc')
if not os.path.exists(outDir):
    os.makedirs(outDir)

# %% [markdown]
# # Load Data into Pandas Dataframes

# %%
parseFiles = True

# %%
# Load file in
if parseFiles:
    for elFilename in ascFiles:
        # print(elFilename)
        dfTrial,dfMsg,dfFix,dfSacc,dfBlink,dfSamples = ParseEyeLinkAsc(os.path.join(dataDir, elFilename))
        print('Saving results...')
        t = time.time()
        # Get file prefix from original filename
        elFileStart = os.path.splitext(elFilename)[0]
        print(elFileStart)

        # Make master list of dataframes to write
        allDataFrames = [dfTrial,dfMsg,dfFix,dfSacc,dfBlink,dfSamples] # the dataframes
        allNames = ['Trial','Message','Fixation','Saccade','Blink','Sample'] # what they're called
        # Write dataframes to .csv files
        for i in range(len(allNames)):
            outFilename = '%s/%s_%s.csv'%(outDir,elFileStart,allNames[i])
            print('   Saving %s output as %s...'%(allNames[i],outFilename))
            allDataFrames[i].to_csv(outFilename,float_format='%.1f',index=False)
        print('Done! Took %f seconds.'%(time.time()-t))
# Out:
# Reading in EyeLink file edf/asc\SV009L.asc...
# Done! Took 0.195906 seconds.
# Sorting lines...
# Done! Took 1.403711 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005003 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.238583 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.244454 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.504078 seconds.
# monocular data detected (L eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.6 seconds.
# Saving results...
# SV009L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV009L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV009L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV009L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV009L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV009L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV009L_Sample.csv...
# Done! Took 1.795645 seconds.
# Reading in EyeLink file edf/asc\SV009R.asc...
# Done! Took 0.202507 seconds.
# Sorting lines...
# Done! Took 1.335367 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.004999 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.216971 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.227393 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.460966 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.6 seconds.
# Saving results...
# SV009R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV009R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV009R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV009R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV009R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV009R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV009R_Sample.csv...
# Done! Took 1.689882 seconds.
# Reading in EyeLink file edf/asc\SV012L.asc...
# Done! Took 0.266998 seconds.
# Sorting lines...
# Done! Took 1.785356 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005002 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.301592 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.317470 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.617745 seconds.
# monocular data detected (L eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.7 seconds.
# Saving results...
# SV012L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV012L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV012L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV012L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV012L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV012L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV012L_Sample.csv...
# Done! Took 1.946527 seconds.
# Reading in EyeLink file edf/asc\SV012R.asc...
# Done! Took 0.244022 seconds.
# Sorting lines...
# Done! Took 1.687684 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.004974 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.273479 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.281020 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.566949 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.7 seconds.
# Saving results...
# SV012R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV012R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV012R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV012R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV012R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV012R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV012R_Sample.csv...
# Done! Took 1.854624 seconds.
# Reading in EyeLink file edf/asc\SV013L.asc...
# Done! Took 0.049668 seconds.
# Sorting lines...
# Done! Took 0.320663 seconds.
# Parsing recording markers...
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.002031 seconds.
# Parsing fixations...
# Done! Took 0.056013 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.055980 seconds.
# Parsing blinks...
# Done! Took 0.117385 seconds.
# monocular data detected (L eye).
# Parsing samples...
# Done! Took 0.1 seconds.
# Saving results...
# SV013L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV013L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV013L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV013L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV013L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV013L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV013L_Sample.csv...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.387092 seconds.
# Reading in EyeLink file edf/asc\SV013R.asc...
# Done! Took 0.314626 seconds.
# Sorting lines...
# Done! Took 2.131736 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005689 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.371670 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.353982 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.711942 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.9 seconds.
# Saving results...
# SV013R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV013R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV013R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV013R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV013R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV013R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV013R_Sample.csv...
# Done! Took 2.345087 seconds.
# Reading in EyeLink file edf/asc\SV017L.asc...
# Done! Took 0.207113 seconds.
# Sorting lines...
# Done! Took 1.427485 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005001 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.235308 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.232064 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.478187 seconds.
# monocular data detected (L eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.6 seconds.
# Saving results...
# SV017L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV017L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV017L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV017L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV017L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV017L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV017L_Sample.csv...
# Done! Took 1.601421 seconds.
# Reading in EyeLink file edf/asc\SV017R.asc...
# Done! Took 0.165460 seconds.
# Sorting lines...
# Done! Took 1.093457 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.004998 seconds.
# Parsing fixations...
# Done! Took 0.197755 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.194392 seconds.
# Parsing blinks...
# Done! Took 0.382439 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.5 seconds.
# Saving results...
# SV017R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV017R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV017R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV017R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV017R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV017R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV017R_Sample.csv...
# Done! Took 1.284547 seconds.
# Reading in EyeLink file edf/asc\SV018L.asc...
# Done! Took 0.195168 seconds.
# Sorting lines...
# Done! Took 1.282506 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.004999 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.217611 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.220512 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.439457 seconds.
# monocular data detected (L eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.6 seconds.
# Saving results...
# SV018L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV018L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV018L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV018L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV018L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV018L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV018L_Sample.csv...
# Done! Took 1.549310 seconds.
# Reading in EyeLink file edf/asc\SV018R.asc...
# Done! Took 0.213454 seconds.
# Sorting lines...
# Done! Took 1.518273 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005000 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.246085 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.274367 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.520010 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.6 seconds.
# Saving results...
# SV018R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV018R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV018R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV018R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV018R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV018R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV018R_Sample.csv...
# Done! Took 1.734613 seconds.
# Reading in EyeLink file edf/asc\SV019L.asc...
# Done! Took 0.187452 seconds.
# Sorting lines...
# Done! Took 1.341474 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005000 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.237945 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.258478 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.535032 seconds.
# monocular data detected (L eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.6 seconds.
# Saving results...
# SV019L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV019L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV019L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV019L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV019L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV019L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV019L_Sample.csv...
# Done! Took 1.597068 seconds.
# Reading in EyeLink file edf/asc\SV019R.asc...
# Done! Took 0.268148 seconds.
# Sorting lines...
# Done! Took 1.812953 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005996 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.299200 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.317795 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.621808 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.7 seconds.
# Saving results...
# SV019R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV019R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV019R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV019R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV019R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV019R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV019R_Sample.csv...
# Done! Took 2.061343 seconds.
# Reading in EyeLink file edf/asc\SV020L.asc...
# Done! Took 0.244128 seconds.
# Sorting lines...
# Done! Took 1.722913 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.007597 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.283670 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.284789 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.638427 seconds.
# monocular data detected (L eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.7 seconds.
# Saving results...
# SV020L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV020L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV020L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV020L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV020L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV020L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV020L_Sample.csv...
# Done! Took 1.932187 seconds.
# Reading in EyeLink file edf/asc\SV020R.asc...
# Done! Took 0.209244 seconds.
# Sorting lines...
# Done! Took 1.616461 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.007015 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.260197 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.257445 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.532471 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.6 seconds.
# Saving results...
# SV020R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV020R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV020R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV020R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV020R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV020R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV020R_Sample.csv...
# Done! Took 1.731946 seconds.
# Reading in EyeLink file edf/asc\SV021L.asc...
# Done! Took 0.286989 seconds.
# Sorting lines...
# Done! Took 1.992731 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005029 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.328536 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.337847 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.691725 seconds.
# monocular data detected (L eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.9 seconds.
# Saving results...
# SV021L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV021L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV021L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV021L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV021L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV021L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV021L_Sample.csv...
# Done! Took 2.209161 seconds.
# Reading in EyeLink file edf/asc\SV021R.asc...
# Done! Took 0.271264 seconds.
# Sorting lines...
# Done! Took 1.946501 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.007002 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.340627 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.344693 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.665213 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 0.8 seconds.
# Saving results...
# SV021R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV021R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV021R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV021R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV021R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV021R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV021R_Sample.csv...
# Done! Took 2.219809 seconds.
# Reading in EyeLink file edf/asc\SV022L.asc...
# Done! Took 0.291381 seconds.
# Sorting lines...
# Done! Took 2.001320 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 2 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.006002 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.341637 seconds.
# Parsing saccades...
# ...
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.546802 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 1.098899 seconds.
# monocular data detected (L eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 1.4 seconds.
# Saving results...
# SV031L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV031L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV031L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV031L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV031L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV031L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV031L_Sample.csv...
# Done! Took 3.723668 seconds.
# Reading in EyeLink file edf/asc\SV031R.asc...
# Done! Took 0.329282 seconds.
# Sorting lines...
# Done! Took 2.149344 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005996 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.453959 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.470546 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.900880 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 1.0 seconds.
# Saving results...
# SV031R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV031R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV031R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV031R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV031R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV031R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV031R_Sample.csv...
# Done! Took 2.951879 seconds.
# Reading in EyeLink file edf/asc\SV032L.asc...
# Done! Took 0.308886 seconds.
# Sorting lines...
# Done! Took 2.039712 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005000 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.411909 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.442552 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.882924 seconds.
# monocular data detected (L eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 1.0 seconds.
# Saving results...
# SV032L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV032L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV032L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV032L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV032L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV032L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV032L_Sample.csv...
# Done! Took 2.938487 seconds.
# Reading in EyeLink file edf/asc\SV032R.asc...
# Done! Took 0.355355 seconds.
# Sorting lines...
# Done! Took 2.325741 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 2 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005981 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.444552 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.475067 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 0.914673 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 1.0 seconds.
# Saving results...
# SV032R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV032R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV032R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV032R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV032R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV032R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV032R_Sample.csv...
# Done! Took 3.070747 seconds.
# Reading in EyeLink file edf/asc\SV033L.asc...
# Done! Took 0.609456 seconds.
# Sorting lines...
# Done! Took 3.854870 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005998 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.736377 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.780807 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 1.539300 seconds.
# monocular data detected (L eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 2.2 seconds.
# Saving results...
# SV033L
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV033L_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV033L_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV033L_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV033L_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV033L_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV033L_Sample.csv...
# Done! Took 5.096938 seconds.
# Reading in EyeLink file edf/asc\SV033R.asc...
# Done! Took 0.363635 seconds.
# Sorting lines...
# Done! Took 3.108358 seconds.
# Parsing recording markers...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:68: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecStart = pd.read_csv(elFilename,skiprows=iNotStart,header=None,delim_whitespace=True,usecols=[1])
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:71: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfRecEnd = pd.read_csv(elFilename,skiprows=iNotEnd,header=None,delim_whitespace=True,usecols=[1,5,6])
# 1 recording periods found.
# Parsing stimulus messages...
# Done! Took 0.005022 seconds.
# Parsing fixations...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:100: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfFix = pd.read_csv(elFilename,skiprows=iNotEfix,header=None,delim_whitespace=True,usecols=range(1,8))
# Done! Took 0.530980 seconds.
# Parsing saccades...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:109: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSacc = pd.read_csv(elFilename,skiprows=iNotEsacc,header=None,delim_whitespace=True,usecols=range(1,11))
# Done! Took 0.544050 seconds.
# Parsing blinks...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:116: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfBlink = pd.read_csv(elFilename,skiprows=iNotEblink,header=None,delim_whitespace=True,usecols=range(1,5))
# Done! Took 1.042954 seconds.
# monocular data detected (R eye).
# Parsing samples...
# c:\Users\Ailene\Desktop\GitHub\blindspot-multisensory\Data\ParseEyeLinkAsc.py:133: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfSamples = pd.read_csv(elFilename,skiprows=iNotSample,header=None,delim_whitespace=True,
# Done! Took 1.2 seconds.
# Saving results...
# SV033R
#    Saving Trial output as edf/asc\ParseEyeLinkAsc/SV033R_Trial.csv...
#    Saving Message output as edf/asc\ParseEyeLinkAsc/SV033R_Message.csv...
#    Saving Fixation output as edf/asc\ParseEyeLinkAsc/SV033R_Fixation.csv...
#    Saving Saccade output as edf/asc\ParseEyeLinkAsc/SV033R_Saccade.csv...
#    Saving Blink output as edf/asc\ParseEyeLinkAsc/SV033R_Blink.csv...
#    Saving Sample output as edf/asc\ParseEyeLinkAsc/SV033R_Sample.csv...
# Done! Took 3.238579 seconds.

# %%
# Go through *_Message files and extract number of trials
msgFiles = [file for file in os.listdir(outDir) if file.endswith('Message.csv')]
fileList = []
nTrials = []
for msgFile in msgFiles:
    df = pd.read_csv(os.path.join(outDir,msgFile))
    # print(df)
    fileList.append(msgFile.split('_Message')[0])
    nTrials.append(sum('TRIAL_END' in text for text in df['text']))
    # print(f"file: {fileList[-1]}, nTrials: {nTrials[-1]}")

    dump_folder = os.path.join(outDir, 'dump')
    if not os.path.exists(dump_folder):
        os.makedirs(dump_folder)

    if nTrials[-1] == 0:
        print(fileList[-1] + ' has no trials! Moving to dump folder...')
        dumpFiles = [file for file in os.listdir(outDir) if file.startswith(fileList[-1])]
        for file in dumpFiles:
            shutil.move(os.path.join(outDir, file), os.path.join(dump_folder, file))
        

data = pd.DataFrame.from_dict({'File': fileList, 'nTrials': nTrials})
data.to_csv(os.path.join(outDir, 'allSub_nTrials.csv'), index=False)

# %% [markdown]
# ## Get Gaze Data

# %%
## Generate time stamps of fixation, stim and resp data
# Messages to look for: FIX_START, FIX_END, FIX_FAILED, FIX_SUCCEED
# Files needed: *_Message.csv, *_Sample.csv

msg_dict = {
    'trialID': 'TRIALID ',
    'fixStart': 'FIX_START',
    'fixEnd': 'FIX_END',
    'fixFailed': 'FIX_FAILED',
    'fixSucceed': 'FIX_SUCCEED',
    'stimStart': 'STIM_START',
    'stimEnd': 'STIM_END',
    'respStart': 'RESP_START',
    'respEnd': 'RESP_END'
}

# keys = ['trialID', 'fixStart', 'fixEnd', 'fixFailed', 'fixSucceed', 'stimStart','stimEnd','respStart','respEnd']
msgFiles = [file for file in os.listdir(outDir) if file.endswith('Message.csv')]

for msgFile in msgFiles:
    df = pd.read_csv(os.path.join(outDir,msgFile))
    # print(df)
    timeStamps = pd.DataFrame()

    # timeStamps['file'] = msgFile.split('_Message')[0]

    for key, msg in msg_dict.items():
        if key == 'trialID':
            timeStamps[key] = pd.Series(
                [df['text'][index].split('TRIALID ')[1] for index, text in enumerate(df['text']) if 'TRIALID' in text],
                dtype='int'
            )
        else:
            timeStamps[key] = df.loc[df['text'].str.contains(msg, na=False), 'time'].reset_index(drop=True)

    timeStamps.to_csv(os.path.join(outDir, msgFile.split('_Message')[0] + '_timeStamps.csv'), index=False)

# %%
def getNormXYarray(x, y):
    resolution = (3840, 2160)
    xCenter = resolution[0] / 2
    yCenter = resolution[1] / 2
    
    xNorm = x - xCenter
    yNorm = y - yCenter
    return pixelToDegree(xNorm), pixelToDegree(yNorm)

def getNormDistFromCenter(x, y):
    resolution = (3840, 2160)
    xCenter = resolution[0] / 2
    yCenter = resolution[1] / 2

    xNorm = x - xCenter
    yNorm = y - yCenter

    # Ensure xNorm and yNorm are numpy arrays
    xNorm = np.array(xNorm, dtype=float)
    yNorm = np.array(yNorm, dtype=float)
    
    # Identify NaN values
    if np.isnan(xNorm).any() or np.isnan(yNorm).any():
        # print("NaN values found in the input arrays")
        # Handle NaN values (e.g., replace with zero)
        xNorm = np.nan_to_num(xNorm)
        yNorm = np.nan_to_num(yNorm)
    
    return pixelToDegree(np.sqrt(xNorm**2 + yNorm**2))

def plotSeries(x,y,title):
    mean_x = np.mean(x, axis=0)
    mean_y = np.mean(y, axis=0)
    std_x = np.std(x, axis=0)
    std_y = np.std(y, axis=0)

    # X-axis values (time or sample index)
    x_values = np.arange(mean_x.size)

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(x_values, mean_x, label='Horizontal', color = 'magenta')
    plt.fill_between(x_values, mean_x - std_x, mean_x + std_x, color='magenta', alpha=0.5)
    plt.plot(x_values, mean_y, label='Vertical', color = 'turquoise')
    plt.fill_between(x_values, mean_y - std_y, mean_y + std_y, color='turquoise', alpha=0.5)

    plt.ylim(-.05, .05)
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Distance from center (deg)')
    plt.legend()
    plt.show()

def plotSeries_combined(fixX, fixY, stimX, stimY, respX, respY, title):
    mean_fixX = np.mean(fixX, axis=0)
    mean_fixY = np.mean(fixY, axis=0)
    std_fixX = np.std(fixX, axis=0)
    std_fixY = np.std(fixY, axis=0)

    mean_stimX = np.mean(stimX, axis=0)
    mean_stimY = np.mean(stimY, axis=0)
    std_stimX = np.std(stimX, axis=0)
    std_stimY = np.std(stimY, axis=0)

    mean_respX = np.mean(respX, axis=0)
    mean_respY = np.mean(respY, axis=0)
    std_respX = np.std(respX, axis=0)
    std_respY = np.std(respY, axis=0)

    x_values = np.arange(mean_fixX.size+mean_stimX.size+mean_respX.size)

    plt.figure(figsize=(10, 6))
    plt.plot(x_values, np.concatenate((mean_fixX, mean_stimX, mean_respX)), label='Horizontal', color = 'magenta')
    plt.fill_between(x_values, np.concatenate((mean_fixX - std_fixX, mean_stimX - std_stimX, mean_respX - std_respX)), np.concatenate((mean_fixX + std_fixX, mean_stimX + std_stimX, mean_respX + std_respX)), color='magenta', alpha=0.5)
    plt.plot(x_values, np.concatenate((mean_fixY, mean_stimY, mean_respY)), label='Vertical', color = 'turquoise')
    plt.fill_between(x_values, np.concatenate((mean_fixY - std_fixY, mean_stimY - std_stimY, mean_respY - std_respY)), np.concatenate((mean_fixY + std_fixY, mean_stimY + std_stimY, mean_respY + std_respY)), color='turquoise', alpha=0.5)

    # add dotted line to indicate stimulus onset and offset
    plt.axvline(x=mean_fixX.size, color='black', linestyle='dotted')
    plt.axvline(x=mean_fixX.size+mean_stimX.size, color='black', linestyle='dotted')

    plt.ylim(-.05, .05)
    plt.xticks([])
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Distance from center (deg)')
    plt.legend()

    # save figure
    # plt.savefig(os.path.join(outDir, 'plot', title + '.png'))

    plt.show()

def plotSeries_combined_dist_from_center(fix, stim, resp, eye, color):
    mean_fix = np.mean(fix, axis=0)
    std_fix = np.std(fix, axis=0)

    mean_stim = np.mean(stim, axis=0)
    std_stim = np.std(stim, axis=0)

    mean_resp = np.mean(resp, axis=0)
    std_resp = np.std(resp, axis=0)

    x_values = np.arange(mean_fix.size+mean_stim.size+mean_resp.size)

    plt.figure(figsize=(10, 6))
    plt.plot(x_values, np.concatenate((mean_fix, mean_stim, mean_resp)), label=eye, color=color)
    plt.fill_between(x_values, np.concatenate((mean_fix - std_fix, mean_stim - std_stim, mean_resp - std_resp)), np.concatenate((mean_fix + std_fix, mean_stim + std_stim, mean_resp + std_resp)), color='magenta', alpha=0.5)
    

def pixelToDegree(pix):
    resolution = (3840, 2160)
    screen_width = 600 # mm
    viewing_dist = 570 # mm
    pixel_size = screen_width / resolution[0]
    return 2 * np.arctan(pix * pixel_size / (2 * viewing_dist))

# %%
def getXYarray(ts_df, samp_df, nSamps, keywords, eye):

    x = [] #np.zeros((ts_df['trialID'].size, nSamps))
    y = [] #np.zeros((ts_df['trialID'].size, nSamps))

    # Skip the last 8 rows in ts_df
    ts_df = ts_df[:-8]

    for index, row in ts_df.iterrows():
       
        samples = samp_df[(samp_df['tSample'] >= row[keywords[0]]) & (samp_df['tSample'] < row[keywords[1]])]     
        samples = samples[-nSamps:]
       
        x.append(samples[eye+'X'].values)        
        y.append(samples[eye+'Y'].values)

    # Find the minimum length of the arrays
    min_length = min(len(arr) for arr in x)

    # Truncate the arrays to the minimum length, keeping the last 'min_length' entries
    x_truncated = np.array([arr[-min_length:] for arr in x])
    y_truncated = np.array([arr[-min_length:] for arr in y])
    
    # Debugging output
    # print(f"x_array shape: {x_truncated.shape}")
    # print(f"y_array shape: {y_truncated.shape}")
   
    return x_truncated, y_truncated

# %%
subjectIDs = list(set([file.split('L_')[0] for file in os.listdir(outDir) if file.endswith('Message.csv') and 'L' in file]))
indivPlotDir = os.path.join(plotDir, 'indiv')
if not os.path.exists(indivPlotDir):
    os.makedirs(indivPlotDir)

for sid in subjectIDs:
    plt.figure(figsize=(10, 6))
                  
    for eye, color in zip(['L', 'R'], ['magenta', 'turquoise']):  
        timeStampFiles = [file for file in os.listdir(outDir) if file.endswith('timeStamps.csv') and sid + eye in file]
        sampFiles = [file for file in os.listdir(outDir) if file.endswith('Sample.csv') and sid + eye in file]
        print(f"Processing {eye} eye for subject {sid}")
        print(f"Found sampFiles: {sampFiles}")

        if len(timeStampFiles) == 1:
            ts_df = pd.read_csv(os.path.join(outDir, timeStampFiles[0]))
            samp_df = pd.read_csv(os.path.join(outDir, sampFiles[0]))            
        else:
            for ts_file in timeStampFiles:
                # skip if number of trials == 8
                ts_df = pd.read_csv(os.path.join(outDir, ts_file))
                if ts_df['trialID'].size == 8:
                    continue
                else:
                    sampFile = [file for file in sampFiles if ts_file.split('_timeStamps')[0] in file][0]
                    samp_df = pd.read_csv(os.path.join(outDir, sampFile))
        

        # Fixation duration = 500ms, recorded at 500 Hz, monocular viewing -> every other sample -> 125 samples
        fix_samps_x, fix_samps_y = getXYarray(ts_df, samp_df, 100, ['fixStart', 'fixEnd'], eye)        
        stim_samps_x, stim_samps_y = getXYarray(ts_df, samp_df, 62, ['stimStart', 'stimEnd'], eye)
        resp_samps_x, resp_samps_y = getXYarray(ts_df, samp_df, 100, ['respStart', 'respEnd'], eye)
        
        fix = getNormDistFromCenter(fix_samps_x, fix_samps_y)
        stim = getNormDistFromCenter(stim_samps_x, stim_samps_y)
        resp = getNormDistFromCenter(resp_samps_x, resp_samps_y)

        # plotSeries_combined_dist_from_center(fix, stim, resp, eye, color)
        mean_fix = np.mean(fix, axis=0)
        std_fix = np.std(fix, axis=0)

        mean_stim = np.mean(stim, axis=0)
        std_stim = np.std(stim, axis=0)

        mean_resp = np.mean(resp, axis=0)
        std_resp = np.std(resp, axis=0)

        x_values = np.arange(mean_fix.size+mean_stim.size+mean_resp.size)

        plt.plot(x_values, np.concatenate((mean_fix, mean_stim, mean_resp)), label=eye, color=color)
        plt.fill_between(x_values, np.concatenate((mean_fix - std_fix, mean_stim - std_stim, mean_resp - std_resp)), np.concatenate((mean_fix + std_fix, mean_stim + std_stim, mean_resp + std_resp)), color=color, alpha=0.5)
        

    ymin = -.03
    ymax = .2
    plt.ylim(ymin, ymax)
    # Add dotted lines to indicate stimulus onset and offset
    plt.axvline(x=mean_fix.size, color='black', linestyle='dotted')
    plt.axvline(x=mean_fix.size + mean_stim.size, color='black', linestyle='dotted')
    plt.axhline(y=0, color='black', linestyle=':')
    x_offset = -14
    y_offset = ymin+0.005
    plt.text(mean_fix.size+x_offset, y_offset, 'Stim ON', color='black', fontsize=12)
    plt.text(mean_fix.size+mean_stim.size+x_offset, y_offset, 'Stim OFF', color='black', fontsize=12)

    x_offset = 10
    y_offset = ymax-.01
    plt.text(0+x_offset, y_offset, 'Fixation', color='black', fontsize=12)
    plt.text(mean_fix.size+x_offset, y_offset, 'Stimulus', color='black', fontsize=12)
    plt.text(mean_fix.size+mean_stim.size+x_offset, y_offset, 'Response', color='black', fontsize=12)

    plt.xlim(left=0, right=mean_fix.size+mean_stim.size+mean_resp.size)
    plt.xticks([])
    plt.title(sid, fontsize=16)
    plt.xlabel('Time', fontsize=16) #, rotation=270)
    plt.ylabel('Gaze distance from fixation cross (deg)', fontsize=16) #, rotation=270, labelpad=20)
    plt.legend(loc='lower left')

    # save figure
    plt.savefig(os.path.join(indivPlotDir, sid + '.png'))
    # plt.show()
    plt.close()
# Out:
# Processing L eye for subject SV033
# Found sampFiles: ['SV033L_Sample.csv']
# Processing R eye for subject SV033
# Found sampFiles: ['SV033R_Sample.csv']
# Processing L eye for subject SV012
# Found sampFiles: ['SV012L_Sample.csv']
# Processing R eye for subject SV012
# Found sampFiles: ['SV012R_Sample.csv']
# Processing L eye for subject SV022
# Found sampFiles: ['SV022L_Sample.csv']
# Processing R eye for subject SV022
# Found sampFiles: ['SV022R_Sample.csv']
# Processing L eye for subject SV026
# Found sampFiles: ['SV026L_Sample.csv']
# Processing R eye for subject SV026
# Found sampFiles: ['SV026R_Sample.csv']
# Processing L eye for subject SV029
# Found sampFiles: ['SV029L_Sample.csv']
# Processing R eye for subject SV029
# Found sampFiles: ['SV029R_Sample.csv']
# Processing L eye for subject SV030
# Found sampFiles: ['SV030L_Sample.csv']
# Processing R eye for subject SV030
# Found sampFiles: ['SV030R_Sample.csv']
# Processing L eye for subject SV013
# Found sampFiles: ['SV013L_Sample.csv']
# Processing R eye for subject SV013
# Found sampFiles: ['SV013R_Sample.csv']
# Processing L eye for subject SV027
# Found sampFiles: ['SV027L_Sample.csv']
# Processing R eye for subject SV027
# Found sampFiles: ['SV027R_Sample.csv']
# Processing L eye for subject SV019
# Found sampFiles: ['SV019L_Sample.csv']
# Processing R eye for subject SV019
# Found sampFiles: ['SV019R_Sample.csv']
# Processing L eye for subject SV009
# Found sampFiles: ['SV009L_Sample.csv']
# Processing R eye for subject SV009
# Found sampFiles: ['SV009R_Sample.csv']
# Processing L eye for subject SV025
# Found sampFiles: ['SV025L_Sample.csv']
# Processing R eye for subject SV025
# Found sampFiles: ['SV025R_Sample.csv']
# Processing L eye for subject SV024
# Found sampFiles: ['SV024L_Sample.csv']
# Processing R eye for subject SV024
# Found sampFiles: ['SV024R_Sample.csv']
# Processing L eye for subject SV017
# Found sampFiles: ['SV017L_Sample.csv']
# Processing R eye for subject SV017
# Found sampFiles: ['SV017R_Sample.csv']
# Processing L eye for subject SV023
# Found sampFiles: ['SV023L_Sample.csv']
# Processing R eye for subject SV023
# Found sampFiles: ['SV023R_Sample.csv']
# Processing L eye for subject SV018
# Found sampFiles: ['SV018L_Sample.csv']
# Processing R eye for subject SV018
# Found sampFiles: ['SV018R_Sample.csv']
# Processing L eye for subject SV020
# Found sampFiles: ['SV020L_Sample.csv']
# Processing R eye for subject SV020
# Found sampFiles: ['SV020R_Sample.csv']
# Processing L eye for subject SV031
# Found sampFiles: ['SV031L_Sample.csv']
# Processing R eye for subject SV031
# Found sampFiles: ['SV031R_Sample.csv']
# Processing L eye for subject SV028
# Found sampFiles: ['SV028L_Sample.csv']
# Processing R eye for subject SV028
# Found sampFiles: ['SV028R_Sample.csv']
# Processing L eye for subject SV032
# Found sampFiles: ['SV032L_Sample.csv']
# Processing R eye for subject SV032
# Found sampFiles: ['SV032R_Sample.csv']
# Processing L eye for subject SV021
# Found sampFiles: ['SV021L_Sample.csv']
# Processing R eye for subject SV021
# Found sampFiles: ['SV021R_Sample.csv']

# %%
# Make an array of individual plots
nCols = 3
nRows = 7
fig, axs = plt.subplots(nRows, nCols, figsize=(20, 30))

# just read the png files
# sort subjectIDs
subjectIDs.sort()
for i, sid in enumerate(subjectIDs):
    img = plt.imread(os.path.join(plotDir, 'indiv', sid + '.png'))
    row = i // nCols
    col = i % nCols
    axs[row, col].imshow(img)
    axs[row, col].axis('off')
    # axs[row, col].set_title(sid)

# Remove the last subplot (21st subplot)
fig.delaxes(axs[6, 2])

# Adjust spacing
plt.tight_layout()
plt.savefig(os.path.join(plotDir, 'indiv_plots.png'))

# %% [markdown]
# ## Extras: Group gaze data

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Initialize lists to store group data
group_fix = {'L': [], 'R': []}
group_stim = {'L': [], 'R': []}
group_resp = {'L': [], 'R': []}

subjectIDs = list(set([file.split('L_')[0] for file in os.listdir(outDir) if file.endswith('Message.csv') and 'L' in file]))

for sid in subjectIDs:
    for eye in ['L', 'R']:
        timeStampFiles = [file for file in os.listdir(outDir) if file.endswith('timeStamps.csv') and sid + eye in file]
        sampFiles = [file for file in os.listdir(outDir) if file.endswith('Sample.csv') and sid + eye in file]

        if len(timeStampFiles) == 1:
            ts_df = pd.read_csv(os.path.join(outDir, timeStampFiles[0]))
            samp_df = pd.read_csv(os.path.join(outDir, sampFiles[0]))            
        else:
            for ts_file in timeStampFiles:
                # skip if number of trials == 8
                ts_df = pd.read_csv(os.path.join(outDir, ts_file))
                if ts_df['trialID'].size == 8:
                    continue
                else:
                    sampFile = [file for file in sampFiles if ts_file.split('_timeStamps')[0] in file][0]
                    samp_df = pd.read_csv(os.path.join(outDir, sampFile))
        
        # Fixation duration = 500ms, recorded at 500 Hz, monocular viewing -> every other sample -> 125 samples
        fix_samps_x, fix_samps_y = getXYarray(ts_df, samp_df, 100, ['fixStart', 'fixEnd'], eye)
        stim_samps_x, stim_samps_y = getXYarray(ts_df, samp_df, 100, ['stimStart', 'stimEnd'], eye)
        resp_samps_x, resp_samps_y = getXYarray(ts_df, samp_df, 100, ['respStart', 'respEnd'], eye)

        fix = getNormDistFromCenter(fix_samps_x, fix_samps_y)
        stim = getNormDistFromCenter(stim_samps_x, stim_samps_y)
        resp = getNormDistFromCenter(resp_samps_x, resp_samps_y)

        mean_fix = np.mean(fix, axis=0)
        mean_stim = np.mean(stim, axis=0)
        mean_resp = np.mean(resp, axis=0)

        group_fix[eye].append(mean_fix)
        group_stim[eye].append(mean_stim)
        group_resp[eye].append(mean_resp)

# Find the minimum length of the arrays
for eye in ['L', 'R']:
    # fix
    min_length = min(len(arr) for arr in group_fix[eye])
    group_fix[eye] = np.array([arr[-min_length:] for arr in group_fix[eye]])
    print(group_fix[eye].shape)
    # stim
    min_length = min(len(arr) for arr in group_stim[eye])
    group_stim[eye] = np.array([arr[-min_length:] for arr in group_stim[eye]])
    print(group_stim[eye].shape)
    # resp
    min_length = min(len(arr) for arr in group_resp[eye])
    group_resp[eye] = np.array([arr[-min_length:] for arr in group_resp[eye]])
    print(group_resp[eye].shape)
# Out:
# (20, 100)
# (20, 62)
# (20, 100)
# (20, 100)
# (20, 62)
# (20, 100)

# %%
# Plot group data
plt.figure(figsize=(10, 6))

for eye, color in zip(['L', 'R'], ['magenta', 'turquoise']):
    
    # Calculate mean and standard deviation
    mean_fix = np.mean(group_fix[eye], axis=0)
    std_fix = np.std(group_fix[eye], axis=0)
    mean_stim = np.mean(group_stim[eye], axis=0)
    std_stim = np.std(group_stim[eye], axis=0)
    mean_resp = np.mean(group_resp[eye], axis=0)
    std_resp = np.std(group_resp[eye], axis=0)

    x_values = np.arange(mean_fix.size + mean_stim.size + mean_resp.size)

    plt.plot(x_values, np.concatenate((mean_fix, mean_stim, mean_resp)), label=eye, color=color)
    print("distance from center during fixation: ", mean_fix.mean())
    print("std: ", std_fix.mean())
    print("distance from center during stimulus: ", mean_stim.mean())
    print("std: ", std_stim.mean())
    plt.fill_between(x_values, np.concatenate((mean_fix - std_fix, mean_stim - std_stim, mean_resp - std_resp)), np.concatenate((mean_fix + std_fix, mean_stim + std_stim, mean_resp + std_resp)), color=color, alpha=0.5)

ymin = -.03
ymax = .2
plt.ylim(ymin, ymax)
# Add dotted lines to indicate stimulus onset and offset
plt.axvline(x=mean_fix.size, color='black', linestyle='dotted')
plt.axvline(x=mean_fix.size + mean_stim.size, color='black', linestyle='dotted')
plt.axhline(y=0, color='black', linestyle=':')
x_offset = -14
y_offset = ymin+0.005
plt.text(mean_fix.size+x_offset, y_offset, 'Stim ON', color='black', fontsize=12)
plt.text(mean_fix.size+mean_stim.size+x_offset, y_offset, 'Stim OFF', color='black', fontsize=12)

x_offset = 5
y_offset = ymax-.01
plt.text(0+x_offset, y_offset, 'Fixation', color='black', fontsize=12)
plt.text(mean_fix.size+x_offset, y_offset, 'Stimulus', color='black', fontsize=12)
plt.text(mean_fix.size+mean_stim.size+x_offset, y_offset, 'Response', color='black', fontsize=12)

# Set the x-axis and y-axis to start at 0
plt.xlim(left=0, right=mean_fix.size+mean_stim.size+mean_resp.size)

# plt.ylim(bottom=0)
plt.xticks([])
# plt.title('Group (N = %d)'%len(subjectIDs), fontsize=16)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Gaze distance from fixation cross (deg)', fontsize=16)
plt.legend(loc='lower left') 

# Save figure
plt.savefig(os.path.join(plotDir, 'group.png'))
plt.show()
# Out:
# distance from center during fixation:  0.016137266346494532
# std:  0.002792952441811918
# distance from center during stimulus:  0.01721316555858968
# std:  0.003902833173053525
# distance from center during fixation:  0.016569098561876477
# std:  0.003410892001335538
# distance from center during stimulus:  0.01749089331711962
# std:  0.004314378581277044
